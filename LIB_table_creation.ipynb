# %%
import pandas as pd
import numpy as np
import os
import json

# %%
with open('constitutions.json', 'r') as file:
    constitutions = json.load(file)

dem_data = pd.read_csv('merged_democracy_data.csv')

# %% [markdown]
# ## CREATION OF LIB

# %%
lib_list = []
for key in constitutions.keys():
    name_part, date_part = key.rsplit('_', 1)
    country_name = name_part.replace('_', ' ')
    lib_list.append({
    'doc_id': key,
    'country_name': country_name,
    'doc_year': int(date_part),
    'doc_len': len(constitutions[key])
    })

LIB = pd.DataFrame(lib_list).set_index('doc_id')



# 2. Merge LIB with only the latest democracy stats
merged_df = pd.merge(LIB, dem_data, on='country_name', how='left')

# %%
merged_df.head()
# Out:
#   country_name  doc_year  doc_len country_text_id    year  \
# 0  Afghanistan      2004    66806             AFG  2024.0
# 1      Albania      2008    86022             ALB  2024.0
# 2      Algeria      2008    66590             DZA  2024.0
# 3      Andorra      1993    55687             NaN     NaN
# 4       Angola      2010   175148             AGO  2024.0
#
#    electoral_democracy  liberal_democracy  participatory_democracy  \
# 0                0.080              0.014                    0.012
# 1                0.510              0.398                    0.305
# 2                0.260              0.123                    0.094
# 3                  NaN                NaN                      NaN
# 4                0.342              0.161                    0.100
#
#    deliberative_democracy  egalitarian_democracy  ...  presidentialism  \
# 0                   0.024                  0.028  ...            0.944
# 1                   0.256                  0.367  ...            0.293
# 2                   0.169                  0.240  ...            0.818
# 3                     NaN                    NaN  ...              NaN
# 4                   0.161                  0.128  ...            0.754
#
#    civil_liberties  political_exclusion  political_corruption  \
# 0            0.042                  NaN                 0.681
# 1            0.876                  NaN                 0.627
# 2            0.418                  NaN                 0.662
# 3              NaN                  NaN                   NaN
# 4            0.624                  NaN                 0.546
#
#    public_sector_corruption  gender_equality_index  fh_political_rights  \
# 0                     0.686                  0.049                  1.0
# 1                     0.651                  0.901                 28.0
# 2                     0.595                  0.625                 10.0
# 3                       NaN                    NaN                  NaN
# 4                     0.471                  0.757                 10.0
#
#    fh_civil_liberties  fh_total_score  fh_status
# 0                 5.0             6.0         NF
# 1                40.0            68.0         PF
# 2                22.0            32.0         NF
# 3                 NaN             NaN        NaN
# 4                18.0            28.0         NF
#
# [5 rows x 29 columns]

# %%
LIB = merged_df

# %%
LIB = LIB.rename({'doc_year' : 'year_amended', 'year' : 'dem_year'}, axis=1)

# %%
len(LIB)
# Out:
# 192

# %%
np.mean(LIB['doc_len'])
# Out:
# np.float64(138099.45833333334)

# %%
LIB.to_csv('const_LIB.csv')
